# %%
import aerosandbox as asb
import aerosandbox.numpy as np
import matplotlib.pyplot as plt

from dynamics.rigid_body_dynamics.Aircraft2D import Aircraft2DPointMass
from dynamics.AeroModelling.SimpleAircraft2D import ThinAirfoilModel
from aerosandbox.numpy.integrate_discrete import integrate_discrete_squared_curvature as int_desc

# %%
# initialize the optimization problem class
opti = asb.Opti()

# set up the problem as a constant dt problem, initialize different opti.variable instances for each of the 'free' variables
dt = .25
time = np.arange(0,80,dt)
N = np.length(time)
dyn = Aircraft2DPointMass(
    mass = 9.54, # kg # vehicle mass is encoded in the point mass info
    Iyy = 1.83, # kg-m^2 # vehicle rolling inertia contained in point mass info
    x_earth = opti.variable(init_guess=1*np.linspace(1,100,N),upper_bound=1e4,lower_bound=-1),  # [m] earth x-position
    z_earth = opti.variable(init_guess=1*np.linspace(1,100,N),upper_bound=1e4,lower_bound=-1e4), # [m] # earth z-position (altitude)
    w_body = opti.variable(init_guess=0*np.linspace(1,30,N),upper_bound=2,lower_bound=-2), # [m/s] z-component body velocity
    u_body = opti.variable(init_guess=1*np.linspace(1,30,N),upper_bound=30,lower_bound=0), # [m/s] x-component body velocity
    pitch = opti.variable(init_guess=0*np.linspace(1,100,N),upper_bound=45,lower_bound=-45),  # [deg] pitch of the aircraft w.r.t. x-axis in the earth frame
    flap_deflection= 40 * np.ones(time.shape), # [deg] flap deflection angle (+ down)
    #flap_deflection = opti.variable(init_guess=0*np.linspace(1,100,N),upper_bound=50,lower_bound=0), # [deg] horizontal tail deflection angle (+ down)
    elevator_deflection = opti.variable(init_guess=0*np.linspace(1,100,N),upper_bound=10,lower_bound=-10), # [deg] horizontal tail deflection angle (+ down)
    throttle_position = opti.variable(init_guess=0*np.ones(time.shape),upper_bound=1,lower_bound=0) # [-] throttle position from 0-1
    # delta_T=np.zeros(time.shape)
)

# encode aircraft dimensional information into point mass class
dyn.Span = 3.05
dyn.ChordMean = 0.38
dyn.TailSpan = 1.27
dyn.TailChordMean = 0.25
dyn.Area = 1.09
dyn.TailArea = 0.2

# %%
# Initialize the dynamics model (for exactly how it works, enter the ThinAirfoilModel() class file
amodel = ThinAirfoilModel()

# generate the Lift, drag, and moment dyamics equations from the aeromodel, 
L,D,M = amodel.getForcesAndMoments(dyn)
cl,cd,cm = amodel.fullDynamicsModel(dyn)
Thrust = amodel.thrustModel(dyn) # thrust separately to simplify for now

#=================================================
# add constraints to the constraint list

# aero forces added in aero frame
dyn.add_force(D,L,from_axes='wind')
dyn.add_moment(M)

# non-aero forces added in the easiest frame of reference to do out the math
dyn.add_force(0,dyn.Mass*9.81,from_axes='earth')
#dyn.add_force(Thrust,0,from_axes='body')
dyn.add_force(Thrust,0,from_axes='body')
dyn.add_moment(Thrust * 0.1)

# %%
dyn.My_b
# Out:
# MX(@1=(15.5*opti0_x_4), @2=(0.0174533*opti0_x_6), ((0.38*(1.09*((all_1.228(320x1)*(0.5*(sq(@1)-sq(opti0_x_3))))*(all_-0.433483(320x1)-(0.183486*((1.5*(6.28319*(((0.0174533*(57.2958*atan2(opti0_x_3,@1)))+(0.36901*tan(@2)))+(0.5*(0.916515*(0.63662*tan(@2)))))))/0.38))))))+(0.1*(0.4*(93.5874*opti0_x_7)))))

# %%
# start adding constraints. This section contains general contraints (i.e. forward motion, must not be in contact with ground etc) 

# general forward motion and ground boundayr conditions
opti.subject_to([
    dyn.BodyXVelocity >= 0,
    dyn.Altitude >= 0,
    dyn.EarthXPosition >=0,
    dyn.Airspeed >= 0
])



# aero model limitations on AoA ( depends on model)
opti.subject_to([
    dyn.Alpha**2 <=144
])

# ===========================================================
# set simulation - specific limits on control variables and rates

# get rates for directly-controlled state/control variables
throttle_rate = np.diff(dyn.ThrottlePosition) / np.diff(time)
tail_rate = np.diff(dyn.ElevatorPosition) / np.diff(time)
flap_rate = np.diff(dyn.FlapPosition) / np.diff(time)

# set constraints
opti.subject_to([
    flap_rate >= -2,
    flap_rate <= 2,
    tail_rate**2 <= 10,
    dyn.ElevatorPosition**2 <= 100 ,
    dyn.dtheta**2 <= 100,
    dyn.ThrottlePosition >= 0,
    dyn.ThrottlePosition < 1, 
    throttle_rate**2 < 0.2,
    dyn.dtheta**2 <= 5
])
# Out:
# [None,
#  None,
#  MX(fabs(opti0_lam_g_20)),
#  MX(fabs(opti0_lam_g_21)),
#  MX(fabs(opti0_lam_g_22)),
#  MX(fabs(opti0_lam_g_23)),
#  MX(fabs(opti0_lam_g_24)),
#  MX(fabs(opti0_lam_g_25)),
#  MX(fabs(opti0_lam_g_26))]

# %%
# problem specific dynamics constraints including start-end boundary conditions

# start constraints, in general must start at a relatively steady-level flight condition
opti.subject_to([
    dyn.EarthXPosition[0] == 0,  # starting position arbitrarily 0
    dyn.Altitude[0] == 200,  # starting Altitude of 2km (~180 ft),
    # dyn.DeltaThrottle[0] ==0.01, # throttle starts near 0
    dyn.Airspeed[0] == 10
    
])

# general constraints
opti.subject_to([
    dyn.glide_slope[:-5] >= 5,
    dyn.glide_slope[:-5] <= 10
])

# end constraints -- level flight
opti.subject_to([
    dyn.Pitch[-1] > 2,
    dyn.EarthZVelocity[-1]>=0,
    dyn.EarthZVelocity[-1] <= 0.5,
    dyn.Altitude[-5:-1] <=5,
])

# cruise constraints
curv = int_desc(dyn.ElevatorPosition/25,time) + int_desc(dyn.ThrottlePosition,time) + int_desc(dyn.FlapPosition,time)

# cost function for the optimizer to work against
opti.minimize(1e-2*np.sum(curv) + dyn.Altitude[-1] + dyn.Airspeed[-1] + (dyn.EarthXPosition[-1]))

# send constraints to the opti instance
dyn.constrain_derivatives(opti,time,method='cubic')

# %%
# run the optimizaiton problem, if it fails return the last solution. The optimizer is very sensitive to boundary constraints, so it will sometimes fail even though a solution is nearly correct so it is reasonable to inspect those solutions sometimes
try:
    sol = opti.solve(max_iter=3000,behavior_on_failure="return_last",detect_simple_bounds=True)
    dyn = sol(dyn)
    x_e = dyn.EarthXPosition
    z_e = dyn.Altitude
    u = dyn.BodyXVelocity
    w = dyn.BodyZVelocity
    time = sol(time)
    
except RuntimeError:
    dyn = sol(dyn)
    x_e = dyn.EarthXPosition
    z_e = dyn.Altitude
    u = dyn.BodyXVelocity
    w = dyn.BodyZVelocity
    time = sol(time)
# Out:
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...
  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  330r 6.6927936e+02 4.25e+03 1.00e+03   3.3 0.00e+00    -  0.00e+00 4.46e-07R 13
#  331r 7.9767010e+02 5.83e+03 1.38e+04   0.9 1.13e+01    -  6.50e-01 8.79e-01f  1
#  332r 7.6467322e+02 5.49e+03 1.19e+04   0.7 7.89e+00    -  7.59e-01 2.11e-01f  1
#  333r 6.9814683e+02 2.65e+03 5.94e+03   0.5 2.88e+01    -  4.11e-01 6.49e-01f  1
#  334r 6.7114137e+02 2.43e+03 2.05e+03   0.0 8.49e+00    -  7.60e-01 8.07e-01f  1
#  335r 6.6441057e+02 1.69e+03 7.35e+02   0.1 1.62e+01    -  8.62e-01 8.78e-01f  1
#  336r 6.6744110e+02 1.15e+03 2.12e+02  -0.3 1.22e+01    -  9.91e-01 1.00e+00f  1
#  337r 6.6871358e+02 1.03e+03 1.27e+02  -1.2 6.93e+00    -  1.00e+00 5.93e-01f  1
#  338r 6.6938211e+02 9.58e+02 2.99e+01  -0.9 4.55e+00    -  9.99e-01 9.72e-01f  1
#  339r 6.6992393e+02 9.41e+02 1.60e+01  -1.8 8.02e-01    -  9.98e-01 9.15e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  340r 6.7023746e+02 9.41e+02 1.32e+02  -2.2 9.75e-01    -  1.00e+00 5.61e-01f  1
#  341r 6.7054956e+02 9.42e+02 1.55e+02  -2.3 1.05e+00    -  1.00e+00 3.62e-01f  1
#  342r 6.7088672e+02 9.42e+02 3.75e+01  -2.4 7.85e-01    -  1.00e+00 7.93e-01f  1
#  343r 6.7087652e+02 9.41e+02 5.95e+01  -3.0 6.62e-01    -  1.00e+00 7.23e-01f  1
#  344r 6.7075579e+02 9.38e+02 5.32e-01  -3.2 4.27e-01    -  1.00e+00 1.00e+00f  1
#  345r 6.7062919e+02 9.36e+02 4.24e-02  -4.2 2.01e-01    -  1.00e+00 1.00e+00f  1
#  346r 6.7060574e+02 9.35e+02 1.15e-02  -5.7 6.94e-02    -  1.00e+00 9.99e-01f  1
#  347r 6.7060573e+02 9.35e+02 5.03e-01  -6.4 2.29e-02    -  1.00e+00 9.86e-01h  1
#  348r 6.7060570e+02 9.35e+02 3.70e+00  -7.5 2.08e-02    -  1.00e+00 7.89e-01h  1
#  349r 6.7060570e+02 9.35e+02 3.52e-01  -7.7 1.41e-02    -  1.00e+00 9.19e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  350r 6.7060570e+02 9.35e+02 2.52e-05  -9.0 1.39e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 350
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.7060570593324837e+02    6.7060570593324837e+02
# Dual infeasibility......:   5.0499999998286341e+01    5.0499999998286341e+01
# Constraint violation....:   5.8614686660190796e-01    9.3509572513594321e+02
# Variable bound violation:   4.9990310557745943e-08    4.9990310557745943e-08
# Complementarity.........:   1.0009244733249047e-09    1.0009244733249047e-09
# Overall NLP error.......:   5.0499999998286341e+01    9.3509572513594321e+02
#
#
# Number of objective function evaluations             = 1292
# Number of objective gradient evaluations             = 310
# Number of equality constraint evaluations            = 1292
# Number of inequality constraint evaluations          = 1292
# Number of equality constraint Jacobian evaluations   = 366
# Number of inequality constraint Jacobian evaluations = 366
# Number of Lagrangian Hessian evaluations             = 351
# Total seconds in IPOPT                               = 13.674
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  20.82ms ( 16.11us)  20.71ms ( 16.03us)      1292
#        nlp_g  | 109.74ms ( 84.94us) 109.29ms ( 84.59us)      1292
#   nlp_grad_f  |   9.36ms ( 30.00us)   9.30ms ( 29.80us)       312
#   nlp_hess_l  | 300.06ms (890.39us) 300.21ms (890.84us)       337
#    nlp_jac_g  | 446.14ms (  1.22ms) 446.74ms (  1.22ms)       367
#        total  |  13.67 s ( 13.67 s)  13.67 s ( 13.67 s)         1
# /Users/trevorlong/.pyenv/versions/3.12.7/lib/python3.12/site-packages/aerosandbox/optimization/opti.py:728: UserWarning: Optimization failed. Returning last solution.
#   warnings.warn("Optimization failed. Returning last solution.")

# %%
# everything from here on is plotting and plotting to debug and so is not yet totally cleaned. 

from dynamics.rigid_body_dynamics.visualization import visualizeRun2D
fig_dict = visualizeRun2D(time,dyn)

# %%
L,D,M = amodel.getForcesAndMoments(dyn)
cl,cd,cm = amodel.fullDynamicsModel(dyn)
clt,cdt,cmt = amodel.tailDynamicsModel(dyn)
clw,cdw,cmw = amodel.wingDynamicsModel(dyn)
thrust = amodel.thrustModel(dyn)

# %%
plt.plot(time,dyn.EarthZVelocity,label='earth_vert')
plt.plot(time,dyn.Altitude-dyn.Altitude[0],label='alt')
plt.plot(time,dyn.Pitch,label='pitch')
plt.plot(time,dyn.ElevatorPosition,label='elev')


plt.legend()

# %%
  
plt.plot(time,dyn.BodyZVelocity,label='w_e')
plt.plot(time,dyn.BodyXVelocity,label='u_b')
plt.plot(time,dyn.Altitude-dyn.Altitude[0],label='dalt')
plt.legend()

# %%
plt.plot(time,cmw,label='cmw')
plt.plot(time,cmt,label='cmt')
plt.plot(time,cm)
plt.legend()

# %%
plt.plot(time,dyn.Pitch)
plt.plot(time,dyn.DeltaElevator)


plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 plt.plot(time,dyn.Pitch)
# ----> 2 plt.plot(time,dyn.DeltaElevator)
#       5 plt.legend()
#
# AttributeError: 'Aircraft2DPointMass' object has no attribute 'DeltaElevator'

# %%
plt.plot(time,dyn.Fx_b,label='xforce')
plt.plot(time,dyn.Pitch,label='pitch')
plt.plot(time,thrust,label='thrust-force')
fx,fz = dyn.convert_axes(D,0,from_axes='wind',to_axes='body')
plt.plot(time,fx  ,label='drag force')
plt.plot(time,dyn.a_x,label='ax')

plt.legend()

# %%
plt.plot(time,dyn.Airspeed*np.cosd(dyn.Pitch),label='u_e')
# plt.plot(time,dyn.speed*np.sind(dyn.Pitch),label='w_e')
plt.plot(time,dyn.w_e,label='computed w_e')
plt.plot(time,dyn.Pitch,label='pitch')

plt.legend()

# %%
plt.plot(clt)
plt.plot(dyn.alpha)

# %%
plt.figure()

plt.plot(time,dyn.KE-dyn.KE[0],label='KE')
plt.plot(time,dyn.PE-dyn.PE[0],label='PE')
plt.plot(time,dyn.TE-dyn.TE[0],label='TE')
plt.legend()

# %%
dyn.z_e[-1]

# %%
dyn.z_e[0]

# %%
plt.plot(time,cmw)
plt.plot(time,clt,label='clt')
plt.plot(time,cm,label='cm',color='green')
plt.plot(time,dyn.My_b,label='my')
plt.plot(time,dyn.Pitch/100,label='Pitch')

plt.legend()

# %%
plt.plot(dyn.delta_T)

# %%
 np.array([dyn.Pitch,dyn.dtheta]).T

# %%
dyn.BodyXVelocity

# %%
dyn.My_b

# %%
dyn.Altitude
